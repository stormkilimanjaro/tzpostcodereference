# %%
import geopandas as gpd
import matplotlib

# %% [markdown]
# ### Visualize the Districts of Tanzania

# %%
districts = gpd.GeoDataFrame.from_file('GIS_Maps/Districts.shp')
districts.head()
# Out:
#   District_C District_N                                           geometry
# 0         01   Bagamoyo  POLYGON ((38.16551914669473 -6.687696428560113...
# 1         01    Bariadi  POLYGON ((34.03601364248937 -2.211428546439151...
# 2         01     Chunya  POLYGON ((33.0295068477579 -6.865547245108006,...
# 3         01      Geita  (POLYGON ((31.81609341023418 -2.69698948098532...
# 4         01     Iramba  POLYGON ((34.49965169179788 -3.927265640108153...

# %%
districts.plot()

# %% [markdown]
# ### Visualize the Regions of Tanzania

# %%
regions = gpd.GeoDataFrame.from_file('GIS_Maps/Regions.shp')
regions.head()
# Out:
#   Region_Cod Region_Nam                                           geometry
# 0         06      Pwani  (POLYGON ((39.32537671104257 -8.29178383277087...
# 1         24     Simiyu  POLYGON ((33.91068356143285 -2.179864105323645...
# 2         25      Geita  (POLYGON ((31.81682247877717 -2.69945151483568...
# 3         13    Singida  POLYGON ((34.9272512066164 -4.264452310071306,...
# 4         11     Iringa  POLYGON ((34.93466133235484 -6.888906141657969...

# %%
regions.plot()
